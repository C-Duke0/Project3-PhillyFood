# %%
import geopandas as gpd

# Load GeoJSON file
gdf_neighborhoods = gpd.read_file('philadelphia.geojson')

# Check the first few entries to confirm the structure
print(gdf_neighborhoods[['name']].head())
# Out:
#                    name
# 0        Pennypack Park
# 1             Overbrook
# 2  Southwest Germantown
# 3         East Parkside
# 4          Germany Hill

# %%
import pandas as pd

data = pd.read_csv('yelp_academic_dataset_with_price_rating.csv')
# Convert DataFrame to GeoDataFrame
gdf_data = gpd.GeoDataFrame(
    data, 
    geometry=gpd.points_from_xy(data.longitude, data.latitude),
    crs="EPSG:4326"  # Make sure this matches your GeoJSON CRS
)

# %%
# Spatial join - points to polygons
data_with_neighborhoods = gpd.sjoin(gdf_data, gdf_neighborhoods, how="inner", op='intersects')

# Check the results
data_with_neighborhoods.head()
# Out:
# /opt/anaconda3/envs/dev/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3493: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
#                business_id           name_left          address          city  \
# 0   MUTTqe8uqyMdBl186RmNeA            Tuna Bar      205 Race St  Philadelphia
# 29  rVfe1LHo55A2fworkm_jVw           Capofitto  233 Chestnut St  Philadelphia
# 38  8LonS_bxNmCDk3FWiG9lzA  Tomo Sushi & Ramen      228 Arch St  Philadelphia
# 44  SIoCIxjn4jLt2O-4DajWJw        Mac's Tavern    226 Market St  Philadelphia
# 67  AWJyivVwe3t9BO-k8D0ynQ     Cafe Square One      50 S 3rd St  Philadelphia
#
#    state  postal_code   latitude  longitude  stars  review_count  \
# 0     PA        19106  39.953949 -75.143226    4.0           245
# 29    PA        19106  39.948578 -75.145023    4.5           205
# 38    PA        19106  39.951923 -75.144335    4.5           193
# 44    PA        19106  39.949794 -75.144739    3.5           446
# 67    PA        19106  39.948907 -75.146080    4.5           245
#
#                                            attributes Categories  \
# 0   {'RestaurantsReservations': 'True', 'Restauran...   Japanese
# 29  {'RestaurantsPriceRange2': '2', 'BikeParking':...    Italian
# 38  {'Alcohol': "u'none'", 'RestaurantsTakeOut': '...   Japanese
# 44  {'OutdoorSeating': 'True', 'BusinessParking': ...   American
# 67  {'BikeParking': 'False', 'RestaurantsPriceRang...   American
#
#     price_rating                    geometry  index_right name_right  \
# 0            2.0  POINT (-75.14323 39.95395)          109   Old City
# 29           2.0  POINT (-75.14502 39.94858)          109   Old City
# 38           2.0  POINT (-75.14433 39.95192)          109   Old City
# 44           2.0  POINT (-75.14474 39.94979)          109   Old City
# 67           1.0  POINT (-75.14608 39.94891)          109   Old City
#
#                          created_at                       updated_at  \
# 0  2013-03-19 16:41:50.508000+00:00 2013-03-19 16:41:50.743000+00:00
# 29 2013-03-19 16:41:50.508000+00:00 2013-03-19 16:41:50.743000+00:00
# 38 2013-03-19 16:41:50.508000+00:00 2013-03-19 16:41:50.743000+00:00
# 44 2013-03-19 16:41:50.508000+00:00 2013-03-19 16:41:50.743000+00:00
# 67 2013-03-19 16:41:50.508000+00:00 2013-03-19 16:41:50.743000+00:00
#
#     cartodb_id
# 0          110
# 29         110
# 38         110
# 44         110
# 67         110

# %%
# Assuming 'review_count' needs to be summed up
# Assuming 'data_with_neighborhoods' is your GeoDataFrame after the spatial join
data_grouped = data_with_neighborhoods.groupby('name_right')['review_count'].mean().reset_index()

# Rename the column to reflect that it contains averages
data_grouped.rename(columns={'review_count': 'average_review_count'}, inplace=True)

# Check the results
print(data_grouped)
# Out:
#             name_right  average_review_count
# 0              Airport            162.250000
# 1       Allegheny West            219.500000
# 2              Andorra            152.666667
# 3          Bella Vista            290.613636
# 4          Brewerytown            138.000000
# ..                 ...                   ...
# 87    Wissahickon Park            191.000000
# 88         Wissinoming            247.500000
# 89    Woodland Terrace            241.000000
# 90          Wynnefield            332.000000
# 91  Wynnefield Heights            117.000000
#
# [92 rows x 2 columns]

# %%
import folium

# Create a map centered around an appropriate location
m = folium.Map(location=[39.9526, -75.1652], zoom_start=12)

# Create the choropleth map
folium.Choropleth(
    geo_data='philadelphia.geojson',
    name='choropleth',
    data=data_grouped,
    columns=['name_right', 'average_review_count'],
    key_on='feature.properties.name',
    fill_color='YlOrRd',  # Color scheme: can be adjusted
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Review Count per Neighborhood'
).add_to(m)

# Add a layer control to toggle on/off
folium.LayerControl().add_to(m)

# Save the map to an HTML file
map_file = 'neighborhood_review_count_map.html'
m.save(map_file)
print(f"Map has been saved to: {map_file}")
# Out:
# Map has been saved to: neighborhood_review_count_map.html

# %%
import folium
import json
import pandas as pd

# Create a map centered around Philadelphia
m = folium.Map(location=[39.9526, -75.1652], zoom_start=12)

# Create the choropleth map
choropleth = folium.Choropleth(
    geo_data='philadelphia.geojson',
    name='choropleth',
    data=data_grouped,
    columns=['name_right', 'average_review_count'],
    key_on='feature.properties.name',
    fill_color='YlOrRd',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Review Count per Neighborhood'
).add_to(m)

# Load GeoJSON file (make sure it's the same as used in the Choropleth)
geo_json_data = json.load(open('philadelphia.geojson'))

# Add GeoJson layer for tooltips
folium.GeoJson(
    data=geo_json_data,
    style_function=lambda feature: {
        'fillColor': '#ffff00',  
        'color': 'black',
        'weight': 0.5,
        'fillOpacity': 0.2
    },
    tooltip=folium.features.GeoJsonTooltip(
        fields=['name'],  
        aliases=['Neighborhood:'],  
        localize=True,
        sticky=False,
        labels=True,
        style="""
            background-color: #F0EFEF;
            border: 2px solid black;
            border-radius: 3px;
            box-shadow: 3px;
        """,
        max_width=250,
    )
).add_to(m)

# Add a layer control to toggle on/off
folium.LayerControl().add_to(m)

# Save the map to an HTML file
map_file = 'neighborhood_review_count_map_tool.html'
m.save(map_file)
print(f"Map has been saved to: {map_file}")
# Out:
# Map has been saved to: neighborhood_review_count_map_tool.html

# %%
import pandas as pd
import geopandas as gpd
import folium
import json

# Load the GeoJSON file as a GeoDataFrame
gdf_neighborhoods = gpd.read_file('philadelphia.geojson')

# Load the data
data = pd.read_csv('yelp_academic_dataset_with_price_rating.csv')

# Convert DataFrame to GeoDataFrame
gdf_data = gpd.GeoDataFrame(
    data, 
    geometry=gpd.points_from_xy(data.longitude, data.latitude),
    crs="EPSG:4326"  # Make sure this matches your GeoJSON CRS
)

# Perform spatial join - points to polygons
data_with_neighborhoods = gpd.sjoin(gdf_data, gdf_neighborhoods, how="inner", op='intersects')

# Assuming 'review_count' needs to be summed up
# Assuming 'data_with_neighborhoods' is your GeoDataFrame after the spatial join
data_grouped = data_with_neighborhoods.groupby('name_right')['review_count'].mean().reset_index()

# Rename the column to reflect that it contains averages
data_grouped.rename(columns={'review_count': 'average_review_count'}, inplace=True)

# Convert datetime columns to string for JSON serialization
for col in ['created_at', 'updated_at']:
    gdf_neighborhoods[col] = gdf_neighborhoods[col].astype(str)

# Merge GeoDataFrame with aggregated data
gdf_neighborhoods = gdf_neighborhoods.merge(data_grouped, left_on='name', right_on='name_right', how='left')

# Define a color scale
color_scale = cm.linear.YlOrRd_09.scale(
    gdf_neighborhoods['average_review_count'].min(),
    gdf_neighborhoods['average_review_count'].max()
)

# Create the Folium map
m = folium.Map(location=[39.9526, -75.1652], zoom_start=12)


# Add a GeoJson layer using the merged GeoDataFrame
folium.GeoJson(
    gdf_neighborhoods,
    style_function=lambda x: {'fillColor': '#ffff00', 'color': 'black', 'weight': 0.5, 'fillOpacity': 0.7},
    tooltip=folium.features.GeoJsonTooltip(
        fields=['name_right', 'average_review_count'],  # fields from the merged GeoDataFrame
        aliases=['Neighborhood:', 'Average Reviews:'],  # how you want the fields to be labeled in the tooltip
        style="""
            background-color: #F0EFEF;
            border: 2px solid black;
            border-radius: 3px;
            box-shadow: 3px;
        """,
        max_width=250,
    )
).add_to(m)

# Add a layer control to toggle on/off
folium.LayerControl().add_to(m)

# Save the map to an HTML file
map_file = 'trial10.html'
m.save(map_file)
print(f"Map has been saved to: {map_file}")
# Out:
# Map has been saved to: trial10.html
# /opt/anaconda3/envs/dev/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3493: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):

# %%
import folium
import geopandas as gpd
import pandas as pd
import branca.colormap as cm
import json

# Load the GeoJSON file as a GeoDataFrame
gdf_neighborhoods = gpd.read_file('philadelphia.geojson')

# Load the data
data = pd.read_csv('yelp_academic_dataset_with_price_rating.csv')

# Convert DataFrame to GeoDataFrame
gdf_data = gpd.GeoDataFrame(
    data, 
    geometry=gpd.points_from_xy(data.longitude, data.latitude),
    crs="EPSG:4326"
)

# Perform spatial join - points to polygons
data_with_neighborhoods = gpd.sjoin(gdf_data, gdf_neighborhoods, how="inner", op='intersects')

# Calculate average review count and merge with GeoDataFrame
data_grouped = data_with_neighborhoods.groupby('name_right')['review_count'].mean().reset_index()
data_grouped.rename(columns={'review_count': 'average_review_count'}, inplace=True)
gdf_neighborhoods = gdf_neighborhoods.merge(data_grouped, on='name', how='left')

# Define a color scale
color_scale = cm.linear.YlOrRd_09.scale(
    gdf_neighborhoods['average_review_count'].min(),
    gdf_neighborhoods['average_review_count'].max()
)

# Create the Folium map
m = folium.Map(location=[39.9526, -75.1652], zoom_start=12)

# Add a GeoJson layer using the merged GeoDataFrame with dynamic coloring
folium.GeoJson(
    gdf_neighborhoods,
    style_function=lambda feature: {
        'fillColor': color_scale(feature['properties']['average_review_count']) if feature['properties']['average_review_count'] is not None else '#d9d9d9',  # Use the color scale or a default color
        'color': 'black',
        'weight': 0.5,
        'fillOpacity': 0.7
    },
    tooltip=folium.features.GeoJsonTooltip(
        fields=['name_right', 'average_review_count'],  # Make sure these fields are in your GeoDataFrame
        aliases=['Neighborhood:', 'Average Reviews:'],
        style="""
            background-color: #F0EFEF;
            border: 2px solid black;
            border-radius: 3px;
            box-shadow: 3px;
        """,
        max_width=250,
    )
).add_to(m)

# Add a layer control to toggle on/off
folium.LayerControl().add_to(m)

# Save the map to an HTML file
map_file = 'neighborhood_review_count_map.html'
m.save(map_file)
print(f"Map has been saved to: {map_file}")
# Out:
# /opt/anaconda3/envs/dev/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3493: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/gm/s0rky8h92s99_ck2c_50c1y40000gn/T/ipykernel_17454/3220484266.py in ?()
#      22
#      23 # Calculate average review count and merge with GeoDataFrame
#      24 data_grouped = data_with_neighborhoods.groupby('name_right')['review_count'].mean().reset_index()
#      25 data_grouped.rename(columns={'review_count': 'average_review_count'}, inplace=True)
# ---> 26 gdf_neighborhoods = gdf_neighborhoods.merge(data_grouped, on='name', how='left')
#      27
#      28 # Define a color scale
#      29 color_scale = cm.linear.YlOrRd_09.scale(
#
# /opt/anaconda3/envs/dev/lib/python3.10/site-packages/geopandas/geodataframe.py in ?(self, *args, **kwargs)
#    1570         See https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas\
#    1571 .DataFrame.merge.html
#    1572         for more details.
#    1573         """
# -> 1574         result = DataFrame.merge(self, *args, **kwargs)
#    1575         geo_col = self._geometry_column_name
#    1576         if isinstance(result, DataFrame) and geo_col in result:
#    1577             result.__class__ = GeoDataFrame
#
# /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/frame.py in ?(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10483         validate: MergeValidate | None = None,
#   10484     ) -> DataFrame:
#   10485         from pandas.core.reshape.merge import merge
#   10486
# > 10487         return merge(
#   10488             self,
#   10489             right,
#   10490             how=how,
#
# /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/reshape/merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     165             validate=validate,
#     166             copy=copy,
#     167         )
#     168     else:
# --> 169         op = _MergeOperation(
#     170             left_df,
#     171             right_df,
#     172             how=how,
#
# /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/reshape/merge.py in ?(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     787             self.right_join_keys,
#     788             self.join_names,
#     789             left_drop,
#     790             right_drop,
# --> 791         ) = self._get_merge_keys()
#     792
#     793         if left_drop:
#     794             self.left = self.left._drop_labels_or_levels(left_drop)
#
# /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/reshape/merge.py in ?(self)
#    1265                         # Then we're either Hashable or a wrong-length arraylike,
#    1266                         #  the latter of which will raise
#    1267                         rk = cast(Hashable, rk)
#    1268                         if rk is not None:
# -> 1269                             right_keys.append(right._get_label_or_level_values(rk))
#    1270                         else:
#    1271                             # work-around for merge_asof(right_index=True)
#    1272                             right_keys.append(right.index._values)
#
# /opt/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, key, axis)
#    1840             values = self.xs(key, axis=other_axes[0])._values
#    1841         elif self._is_level_reference(key, axis=axis):
#    1842             values = self.axes[axis].get_level_values(key)._values
#    1843         else:
# -> 1844             raise KeyError(key)
#    1845
#    1846         # Check for duplicates
#    1847         if values.ndim > 1:
#
# KeyError: 'name'

# %%
data_grouped.to_json('data_grouped.json', orient='records')
